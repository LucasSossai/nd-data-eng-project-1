# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files('./data/song_data')

# %%
filepath = song_files[0]

# %%
df = pd.read_json(filepath,lines=True)
df.head()
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARLTWXK1187FB5A3F8         32.74863         -97.32925
#
#   artist_location  artist_name             song_id  \
# 0  Fort Worth, TX  King Curtis  SODREIN12A58A7F2E5
#
#                                            title   duration  year
# 0  A Whiter Shade Of Pale (Live @ Fillmore West)  326.00771     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[['song_id','title','artist_id','year','duration']].values[0].tolist()
song_data
# Out:
# ['SODREIN12A58A7F2E5',
#  'A Whiter Shade Of Pale (Live @ Fillmore West)',
#  'ARLTWXK1187FB5A3F8',
#  0,
#  326.00771]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[['artist_id','artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']].values[0].tolist()
artist_data
# Out:
# ['ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', 32.74863, -97.32925]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files('data/log_data')

# %%
filepath = log_files[0]

# %%
df = pd.read_json(filepath, lines=True)
df.head()
# Out:
#                  artist       auth firstName gender  itemInSession lastName  \
# 0              Mudhoney  Logged In    Aleena      F             10    Kirby
# 1            Carpenters  Logged In    Aleena      F             11    Kirby
# 2                  None  Logged In    Aleena      F             12    Kirby
# 3         Kings Of Leon  Logged In    Aleena      F             13    Kirby
# 4  The Bloody Beetroots  Logged In    Aleena      F             14    Kirby
#
#       length level                  location method      page  registration  \
# 0  231.57506  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
# 1  238.39302  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
# 2        NaN  paid  Waterloo-Cedar Falls, IA    GET      Home  1.541023e+12
# 3  185.28608  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
# 4  201.97832  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
#
#    sessionId                         song  status             ts  \
# 0        637               Get Into Yours     200  1542326457796
# 1        637          Yesterday Once More     200  1542326688796
# 2        637                         None     200  1542326691796
# 3        637              Taper Jean Girl     200  1542326926796
# 4        637  Warp 1.9 (feat. Steve Aoki)     200  1542327111796
#
#                                            userAgent userId
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 4  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df =  df[df['page'] == "NextSong"] 
df.head()
# Out:
#                  artist       auth firstName gender  itemInSession lastName  \
# 0              Mudhoney  Logged In    Aleena      F             10    Kirby
# 1            Carpenters  Logged In    Aleena      F             11    Kirby
# 3         Kings Of Leon  Logged In    Aleena      F             13    Kirby
# 4  The Bloody Beetroots  Logged In    Aleena      F             14    Kirby
# 5         Kings Of Leon  Logged In    Aleena      F             15    Kirby
#
#       length level                  location method      page  registration  \
# 0  231.57506  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
# 1  238.39302  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
# 3  185.28608  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
# 4  201.97832  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
# 5  201.79546  paid  Waterloo-Cedar Falls, IA    PUT  NextSong  1.541023e+12
#
#    sessionId                         song  status             ts  \
# 0        637               Get Into Yours     200  1542326457796
# 1        637          Yesterday Once More     200  1542326688796
# 3        637              Taper Jean Girl     200  1542326926796
# 4        637  Warp 1.9 (feat. Steve Aoki)     200  1542327111796
# 5        637                      Revelry     200  1542327312796
#
#                                            userAgent userId
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 4  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44
# 5  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     44

# %%
t = pd.to_datetime(df['ts'],unit='ms')
t.head()
# Out:
# 0   2018-11-16 00:00:57.796
# 1   2018-11-16 00:04:48.796
# 3   2018-11-16 00:08:46.796
# 4   2018-11-16 00:11:51.796
# 5   2018-11-16 00:15:12.796
# Name: ts, dtype: datetime64[ns]

# %%
time_data = (t, t.dt.hour, t.dt.day, t.dt.isocalendar().week, t.dt.month, t.dt.year, t.dt.weekday)
column_labels = ("start_time", "hour", "day", "week", "month", "year", "weekday")

# %%
time_df = pd.concat(time_data,keys=column_labels,axis=1)
time_df.head()
# Out:
#                start_time  hour  day  week  month  year  weekday
# 0 2018-11-16 00:00:57.796     0   16    46     11  2018        4
# 1 2018-11-16 00:04:48.796     0   16    46     11  2018        4
# 3 2018-11-16 00:08:46.796     0   16    46     11  2018        4
# 4 2018-11-16 00:11:51.796     0   16    46     11  2018        4
# 5 2018-11-16 00:15:12.796     0   16    46     11  2018        4

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[['userId','firstName','lastName', 'gender', 'level']].drop_duplicates()
user_df
# Out:
#     userId  firstName   lastName gender level
# 0       44     Aleena      Kirby      F  paid
# 10       6    Cecilia      Owens      F  free
# 17      26       Ryan      Smith      M  free
# 23      88   Mohammad  Rodriguez      M  free
# 27      49      Chloe     Cuevas      F  paid
# 30      80      Tegan     Levine      F  paid
# 73      32       Lily      Burns      F  free
# 80     101     Jayden        Fox      M  free
# 92      83    Stefany      White      F  free
# 115     85    Kinsley      Young      F  paid
# 133     69   Anabelle    Simpson      F  free
# 144     50        Ava   Robinson      F  free
# 161     61     Samuel   Gonzalez      M  free
# 168     77  Magdalene     Herman      F  free
# 171      8     Kaylee    Summers      F  free
# 181     76     Jayden      Duffy      F  free
# 193     86      Aiden       Hess      M  free
# 199     36    Matthew      Jones      M  paid
# 201     90     Andrea     Butler      F  free
# 206     97       Kate    Harrell      F  paid
# 257     24      Layla    Griffin      F  paid
# 365     10     Sylvie       Cruz      F  free

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df['ts'] = pd.to_datetime(df['ts'], unit='ms')

# %%
for index, row in df.iterrows():
    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()

    songid, artistid = results or (None, None)
    # insert songplay record
    print(row)
    songplay_data = (row.ts, row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()
# Out:
# artist                                                    Mudhoney
# auth                                                     Logged In
# firstName                                                   Aleena
# gender                                                           F
# itemInSession                                                   10
# lastName                                                     Kirby
# length                                                   231.57506
# level                                                         paid
# location                                  Waterloo-Cedar Falls, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541022995796.0
# sessionId                                                      637
# song                                                Get Into Yours
# status                                                         200
# ts                                      2018-11-16 00:00:57.796000
# userAgent        Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...
# userId                                                          44
# Name: 0, dtype: object
# artist                                                  Carpenters
# auth                                                     Logged In
# firstName                                                   Aleena
# gender                                                           F
# itemInSession                                                   11
# lastName                                                     Kirby
# length                                                   238.39302
# level                                                         paid
# location                                  Waterloo-Cedar Falls, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541022995796.0
# sessionId                                                      637
# song                                           Yesterday Once More
# status                                                         200
# ts                                      2018-11-16 00:04:48.796000
# userAgent        Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...
# userId                                                          44
# Name: 1, dtype: object
# artist                                               Kings Of Leon
# auth                                                     Logged In
# firstName                                                   Aleena
# gender                                                           F
# itemInSession                                                   13
# lastName                                                     Kirby
# length                                                   185.28608
# level                                                         paid
# location                                  Waterloo-Cedar Falls, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541022995796.0
# sessionId                                                      637
# song                                               Taper Jean Girl
# status                                                         200
# ts                                      2018-11-16 00:08:46.796000
# userAgent        Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...
# userId                                                          44
# Name: 3, dtype: object
# artist                                        The Bloody Beetroots
# auth                                                     Logged In
# firstName                                                   Aleena
# gender                                                           F
# itemInSession                                                   14
# lastName                                                     Kirby
# length                                                   201.97832
# level                                                         paid
# location                                  Waterloo-Cedar Falls, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541022995796.0
# sessionId                                                      637
# song                                   Warp 1.9 (feat. Steve Aoki)
# status                                                         200
# ts                                      2018-11-16 00:11:51.796000
# userAgent        Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...
# userId                                                          44
# Name: 4, dtype: object
# artist                                               Kings Of Leon
# auth                                                     Logged In
# firstName                                                   Aleena
# gender                                                           F
# itemInSession                                                   15
# lastName                                                     Kirby
# length                                                   201.79546
# level                                                         paid
# location                                  Waterloo-Cedar Falls, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541022995796.0
# sessionId                                                      637
# song                                                       Revelry
# status                                                         200
# ts                                      2018-11-16 00:15:12.796000
# userAgent        Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...
# userId                                                          44
# Name: 5, dtype: object
# artist                                                 Euge Groove
# auth                                                     Logged In
# firstName                                                   Aleena
# gender                                                           F
# itemInSession                                                   16
# lastName                                                     Kirby
# length                                                     265.482
# level                                                         paid
# location                                  Waterloo-Cedar Falls, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541022995796.0
# sessionId                                                      637
# song                                                      Tenderly
# status                                                         200
# ts                                      2018-11-16 00:18:33.796000
# userAgent        Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...
# userId                                                          44
# Name: 6, dtype: object
# artist                                                     Soltero
# auth                                                     Logged In
# firstName                                                   Aleena
# gender                                                           F
# itemInSession                                                   17
# lastName                                                     Kirby
# length                                                    249.0771
# level                                                         paid
# location                                  Waterloo-Cedar Falls, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541022995796.0
# sessionId                                                      637
# song                                               Bleeding Hearts
# status                                                         200
# ts                                      2018-11-16 00:22:58.796000
# userAgent        Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...
# userId                                                          44
# Name: 7, dtype: object
# artist                                                     Nirvana
# auth                                                     Logged In
# firstName                                                   Aleena
# gender                                                           F
# itemInSession                                                   18
# lastName                                                     Kirby
# length                                                   257.01832
# level                                                         paid
# location                                  Waterloo-Cedar Falls, IA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541022995796.0
# sessionId                                                      637
# song                                                       Lithium
# status                                                         200
# ts                                      2018-11-16 00:27:07.796000
# userAgent        Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...
# userId                                                          44
# Name: 8, dtype: object
# artist                                             Alliance Ethnik
# auth                                                     Logged In
# firstName                                                  Cecilia
# gender                                                           F
# itemInSession                                                    0
# lastName                                                     Owens
# length                                                   252.21179
# level                                                         free
# location                         Atlanta-Sandy Springs-Roswell, GA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541032432796.0
# sessionId                                                      535
# song                                                 ReprÃÂ©sente
# status                                                         200
# ts                                      2018-11-16 05:28:12.796000
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...
# userId                                                           6
# Name: 10, dtype: object
# artist                                                    Lykke Li
# auth                                                     Logged In
# firstName                                                  Cecilia
# gender                                                           F
# itemInSession                                                    1
# lastName                                                     Owens
# length                                                   232.35873
# level                                                         free
# location                         Atlanta-Sandy Springs-Roswell, GA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541032432796.0
# sessionId                                                      535
# song                                            Melodies & Desires
# status                                                         200
# ts                                      2018-11-16 05:32:24.796000
# userAgent        Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...
# userId                                                           6
# Name: 11, dtype: object
# artist                                   The Coffee Club Orchestra
# auth                                                     Logged In
# firstName                                                     Ryan
# gender                                                           M
# itemInSession                                                    1
# lastName                                                     Smith
# length                                                   386.76853
# level                                                         free
# location                        San Jose-Sunnyvale-Santa Clara, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541016707796.0
# sessionId                                                      622
# song                                                      Overture
# status                                                         200
# ts                                      2018-11-16 08:02:56.796000
# userAgent        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# userId                                                          26
# Name: 17, dtype: object
# artist                                                    Harmonia
# auth                                                     Logged In
# firstName                                                     Ryan
# gender                                                           M
# itemInSession                                                    2
# lastName                                                     Smith
# length                                                   655.77751
# level                                                         free
# location                        San Jose-Sunnyvale-Santa Clara, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541016707796.0
# sessionId                                                      622
# song                                                 Sehr kosmisch
# status                                                         200
# ts                                      2018-11-16 08:09:22.796000
# userAgent        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# userId                                                          26
# Name: 20, dtype: object
# artist                                                 Alicia Keys
# auth                                                     Logged In
# firstName                                                 Mohammad
# gender                                                           M
# itemInSession                                                    2
# lastName                                                 Rodriguez
# length                                                   182.07302
# level                                                         free
# location                   Sacramento--Roseville--Arden-Arcade, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540511766796.0
# sessionId                                                      614
# song                                                    Caged Bird
# status                                                         200
# ts                                      2018-11-16 08:12:59.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          88
# Name: 23, dtype: object
# artist                                       Crosby_ Stills & Nash
# auth                                                     Logged In
# firstName                                                 Mohammad
# gender                                                           M
# itemInSession                                                    3
# lastName                                                 Rodriguez
# length                                                   329.19465
# level                                                         free
# location                   Sacramento--Roseville--Arden-Arcade, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540511766796.0
# sessionId                                                      614
# song                                     Wooden Ships (LP Version)
# status                                                         200
# ts                                      2018-11-16 08:16:01.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          88
# Name: 24, dtype: object
# artist                                                      R.E.M.
# auth                                                     Logged In
# firstName                                                     Ryan
# gender                                                           M
# itemInSession                                                    3
# lastName                                                     Smith
# length                                                     241.162
# level                                                         free
# location                        San Jose-Sunnyvale-Santa Clara, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1541016707796.0
# sessionId                                                      622
# song                What's The Frequency_ Kenneth? (Radio Version)
# status                                                         200
# ts                                      2018-11-16 08:20:17.796000
# userAgent        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# userId                                                          26
# Name: 25, dtype: object
# artist                                                Eric Clapton
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    6
# lastName                                                    Cuevas
# length                                                   323.49995
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                              My Father's Eyes
# status                                                         200
# ts                                      2018-11-16 08:38:02.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 27, dtype: object
# artist                                              Godley & Creme
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    7
# lastName                                                    Cuevas
# length                                                   237.81832
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                                           Cry
# status                                                         200
# ts                                      2018-11-16 08:43:25.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 28, dtype: object
# artist                                                  Ron Carter
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    8
# lastName                                                    Cuevas
# length                                                   497.13587
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                           I CAN'T GET STARTED
# status                                                         200
# ts                                      2018-11-16 08:47:22.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 29, dtype: object
# artist                            Timbaland / Keri Hilson / D.O.E.
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    0
# lastName                                                    Levine
# length                                                   179.25179
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                                 The Way I Are
# status                                                         200
# ts                                      2018-11-16 08:54:29.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 30, dtype: object
# artist                                     Everything But The Girl
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                    9
# lastName                                                    Cuevas
# length                                                   295.73179
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                                       Missing
# status                                                         200
# ts                                      2018-11-16 08:55:39.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 31, dtype: object
# artist                                                Big Mountain
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    1
# lastName                                                    Levine
# length                                                   249.52118
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                         Baby_ I Love Your Way (Album Version)
# status                                                         200
# ts                                      2018-11-16 08:57:28.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 32, dtype: object
# artist                                               Gotan Project
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   10
# lastName                                                    Cuevas
# length                                                   315.81995
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                                  Queremos Paz
# status                                                         200
# ts                                      2018-11-16 09:00:34.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 33, dtype: object
# artist                                                  Washed Out
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    2
# lastName                                                    Levine
# length                                                   173.40036
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                                        Belong
# status                                                         200
# ts                                      2018-11-16 09:01:37.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 34, dtype: object
# artist                                                     OutKast
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    3
# lastName                                                    Levine
# length                                                   312.13669
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                            My Favorite Things
# status                                                         200
# ts                                      2018-11-16 09:04:30.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 35, dtype: object
# artist                                               Black Sabbath
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   11
# lastName                                                    Cuevas
# length                                                   388.64934
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                       Symptom Of The Universe
# status                                                         200
# ts                                      2018-11-16 09:05:49.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 36, dtype: object
# artist                                           Late Night Alumni
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    4
# lastName                                                    Levine
# length                                                   226.76853
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                                     Uncharted
# status                                                         200
# ts                                      2018-11-16 09:09:42.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 37, dtype: object
# artist                                            Slightly Stoopid
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   12
# lastName                                                    Cuevas
# length                                                   293.82485
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                                    This Joint
# status                                                         200
# ts                                      2018-11-16 09:12:17.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 38, dtype: object
# artist                                                Beastie Boys
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    5
# lastName                                                    Levine
# length                                                     211.722
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                 Unite (2009 Digital Remaster)
# status                                                         200
# ts                                      2018-11-16 09:13:28.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 39, dtype: object
# artist                                                 The Killers
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    6
# lastName                                                    Levine
# length                                                   222.95465
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                               Who Let You Go?
# status                                                         200
# ts                                      2018-11-16 09:16:59.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 40, dtype: object
# artist                                                   Riverside
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   13
# lastName                                                    Cuevas
# length                                                    236.2771
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                                 Stuck Between
# status                                                         200
# ts                                      2018-11-16 09:17:10.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 41, dtype: object
# artist                                                     Flobots
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    7
# lastName                                                    Levine
# length                                                   246.07302
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                                  Good Soldier
# status                                                         200
# ts                                      2018-11-16 09:20:41.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 42, dtype: object
# artist                                           Lighthouse Family
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   14
# lastName                                                    Cuevas
# length                                                   307.53914
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                                          High
# status                                                         200
# ts                                      2018-11-16 09:21:06.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 43, dtype: object
# artist                                                Jack Johnson
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    8
# lastName                                                    Levine
# length                                                   144.06485
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                               Do You Remember
# status                                                         200
# ts                                      2018-11-16 09:24:47.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 44, dtype: object
# artist                                                     Incubus
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   15
# lastName                                                    Cuevas
# length                                                   229.22404
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                                     Pardon Me
# status                                                         200
# ts                                      2018-11-16 09:26:13.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 45, dtype: object
# artist                                               Edwyn Collins
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                    9
# lastName                                                    Levine
# length                                                   235.91138
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                               A Girl Like You
# status                                                         200
# ts                                      2018-11-16 09:27:11.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 46, dtype: object
# artist                                                Joshua Radin
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   16
# lastName                                                    Cuevas
# length                                                   182.62159
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                       The Fear You Won't Fall
# status                                                         200
# ts                                      2018-11-16 09:30:02.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 47, dtype: object
# artist                                                    Bon Iver
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   17
# lastName                                                    Cuevas
# length                                                   116.89751
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                                          Team
# status                                                         200
# ts                                      2018-11-16 09:33:04.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 48, dtype: object
# artist                                               Nipsey Hussle
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   18
# lastName                                                    Cuevas
# length                                                   170.34404
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      636
# song                                             Its Hard Out Here
# status                                                         200
# ts                                      2018-11-16 09:35:00.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 50, dtype: object
# artist                                               Bebo & Cigala
# auth                                                     Logged In
# firstName                                                    Tegan
# gender                                                           F
# itemInSession                                                   11
# lastName                                                    Levine
# length                                                   331.15383
# level                                                         paid
# location                               Portland-South Portland, ME
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540794356796.0
# sessionId                                                      620
# song                                               Lagrimas Negras
# status                                                         200
# ts                                      2018-11-16 09:41:29.796000
# userAgent        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# userId                                                          80
# Name: 52, dtype: object
# ...
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   39
# lastName                                                    Cuevas
# length                                                     247.562
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                      Miss You
# status                                                         200
# ts                                      2018-11-16 23:02:23.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 367, dtype: object
# artist                                               Eagle Seagull
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   40
# lastName                                                    Cuevas
# length                                                    242.6771
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                              You Can't Call Yourself A Secret
# status                                                         200
# ts                                      2018-11-16 23:06:30.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 368, dtype: object
# artist                                                  Luke Bryan
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   41
# lastName                                                    Cuevas
# length                                                   175.17669
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                          Rain Is A Good Thing
# status                                                         200
# ts                                      2018-11-16 23:10:32.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 369, dtype: object
# artist                                              Steve Ouimette
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   42
# lastName                                                    Cuevas
# length                                                   375.06567
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                The Devil Went Down To Georgia
# status                                                         200
# ts                                      2018-11-16 23:13:27.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 370, dtype: object
# artist                                                  Jill Scott
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   43
# lastName                                                    Cuevas
# length                                                   231.52281
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                        Golden
# status                                                         200
# ts                                      2018-11-16 23:19:42.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 371, dtype: object
# artist                          Edward Sharpe & The Magnetic Zeros
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   44
# lastName                                                    Cuevas
# length                                                   306.31138
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                          Home
# status                                                         200
# ts                                      2018-11-16 23:23:33.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 372, dtype: object
# artist                                                        Muse
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   45
# lastName                                                    Cuevas
# length                                                   346.69669
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                    Resistance
# status                                                         200
# ts                                      2018-11-16 23:28:39.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 373, dtype: object
# artist                                   Usher featuring will.i.am
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   46
# lastName                                                    Cuevas
# length                                                   395.72853
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                           OMG
# status                                                         200
# ts                                      2018-11-16 23:34:25.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 374, dtype: object
# artist                                             Nine Inch Nails
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   47
# lastName                                                    Cuevas
# length                                                   254.71955
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                       Gave Up
# status                                                         200
# ts                                      2018-11-16 23:41:00.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 375, dtype: object
# artist                                             Franz Ferdinand
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   48
# lastName                                                    Cuevas
# length                                                   254.79791
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                     This Fire
# status                                                         200
# ts                                      2018-11-16 23:45:14.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 376, dtype: object
# artist                                                     America
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   49
# lastName                                                    Cuevas
# length                                                   223.97342
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                Tin Man (Live)
# status                                                         200
# ts                                      2018-11-16 23:49:28.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 378, dtype: object
# artist                                              Built To Spill
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   51
# lastName                                                    Cuevas
# length                                                     357.642
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                  Some (Album)
# status                                                         200
# ts                                      2018-11-16 23:53:11.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 380, dtype: object
# artist                                                    Gorillaz
# auth                                                     Logged In
# firstName                                                    Chloe
# gender                                                           F
# itemInSession                                                   52
# lastName                                                    Cuevas
# length                                                   196.91057
# level                                                         paid
# location                         San Francisco-Oakland-Hayward, CA
# method                                                         PUT
# page                                                      NextSong
# registration                                       1540940782796.0
# sessionId                                                      648
# song                                                        Broken
# status                                                         200
# ts                                      2018-11-16 23:59:08.796000
# userAgent        Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# userId                                                          49
# Name: 381, dtype: object

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
